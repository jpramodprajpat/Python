# %%
f = open('file.txt' , 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f = open('file.txt' , 'r')
#
# File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
f = open('file.txt' , 'w')

# %%
f.write('I wrote something')
# Out:
# 17

# %%
f.closed
# Out:
# False

# %%
f.close()

# %%
f.closed
# Out:
# True

# %%
f = open('file.txt' , 'r')

# %%
f.read()
# Out:
# 'I wrote something'

# %%
file = open('file.txt' , 'w')

# %%
file.write("this is first line \n")
file.write("this is second line \n")
file.write("this is third line \n")
file.write("this is fouth line \n")
# Out:
# 20

# %%
file.close()

# %%
f = open('file.txt' , 'w')
f.write("")
f.close()

# %%
f = open('file.txt' , 'a')
f.write("hello 2\n")
f.write("hello 1\n")
f.write("hello 3\n")
f.close()

# %%
file = open('file.txt' , 'r')

# %%
for i in file : 
    print(i)
# Out:
# hello 2
#
# hello 1
#
# hello 3

# %%
print(file.read()) # bcz the cursor/pointer is at last position

# %%
file.tell() # it tells the postion of cursor
# Out:
# 27

# %%
file.seek(0) # brings the cursor at 0
# Out:
# 0

# %%
print(file.read())
# Out:
# hello 2
# hello 1
# hello 3

# %%
file.tell()
# Out:
# 27

# %%
file.seek(0)
# Out:
# 0

# %%
print(file.readline())
# Out:
# hello 2

# %%
file.tell()
# Out:
# 9

# %%
file = open('file.txt' , 'r')

# %%
print(file.readlines())
# Out:
# ['hello 2\n', 'hello 1\n', 'hello 3\n']

# %%
file.tell()
# Out:
# 27

# %%
print(file.readlines())
# Out:
# []

# %%
# To Read any file
- file i in file : print(i)
- read()
- readline()
- readlines()
# positon of cursor or pointer 
- tell()
# to reset position of cursor
- seek(0)

# %%
# to work on directory level -> create , remove , update, rename

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\J Pramod Prajapat\\Desktop\\Python\\file handling'

# %%
os.mkdir('test')

# %%
os.mkdir('test/test2')

# %%
os.makedirs('1/2/3/4')

# %%
os.listdir()
# Out:
# ['1', 'basics.ipynb', 'file.txt', 'test']

# %%
os.mkdir('extra')

# %%
os.rmdir('extra') # it removes directory which has no content inside

# %%
os.rmdir('test') # because test is not empty directory
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 os.rmdir('test') # because test is not empty directory
#
# OSError: [WinError 145] The directory is not empty: 'test'

# %%
import shutil

# %%
shutil.rmtree('test') # it will remove folder hiearchy

# %%
os.getcwd()
# Out:
# 'c:\\Users\\J Pramod Prajapat\\Desktop\\Python\\file handling'

# %%
f = open('1/2/file1.txt', 'w')

# %%
f.close()

# %%
shutil.copy('1/2/file1.txt' , '.')
# Out:
# '.\\file1.txt'
