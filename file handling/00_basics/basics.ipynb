# %%
file = open("demo.txt", "w")

# %%
file.write("Hello, World!\n")
# you will not see the content in the file until you close it
file.close()

# %%
f = open("demo.txt", "r")
file_content = f.read()
print(file_content)
# Out:
# Hello, World!

# %%
f.closed
# Out:
# False

# %%
f.close()
f.closed
# Out:
# True

# %%
#make directory : 
import os
os.mkdir("test")

# %%
os.mkdir("test/test1")

# %%
# Make mulitple directories at once
os.makedirs("1/2/3/4/5")

# %%
# deleting non-empty directory
import shutil
shutil.rmtree(("1"))

# %%
file = open('./test/test1/new_file.text', 'w');
file.write("This is a new file")
file.close()

# %%
# copying file from one location to another
shutil.copy("./test/test1/new_file.text" , "./");

# %%
# to move a file from one location to another
shutil.move('moving_file.text' , "./test");
