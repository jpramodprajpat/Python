# %%
import random

# %% [markdown]
# #  Random choice

# %%
random.choice((1,2,3,4,5,)) # gives you random element
# Out:
# 2

# %%
random.choice("Priya")
# Out:
# 'P'

# %% [markdown]
# # Random Range (int)

# %%
random.randrange(1,10)
# Out:
# 4

# %%
random.randrange()
# Out:
# 0

# %% [markdown]
# # Random (flaot)

# %%
random.random()
# Out:
# 0.7139866518555597

# %% [markdown]
# # Shuffile List

# %%
lis = [1, 2, 3, 4, 5 , 6 , 7]
random.shuffle(lis)
lis
# Out:
# [1, 5, 4, 6, 2, 7, 3]

# %% [markdown]
# # Random in Numpy

# %%
import numpy as np

# %%
np.array([])
# Out:
# array([], dtype=float64)

# %% [markdown]
# # Random_sample : gives you only 1d random data

# %%
np.random.random_sample()
# Out:
# 0.054949089604498624

# %%
np.random.random_sample(4,)
# Out:
# array([0.68380844, 0.59971288, 0.86739   , 0.6641567 ])

# %%
np.random.random_sample(4)
# Out:
# array([0.36438424, 0.13095989, 0.14976491, 0.0351149 ])

# %%
np.random.random_sample(4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 np.random.random_sample(4,5)
#
# File numpy/random/mtrand.pyx:395, in numpy.random.mtrand.RandomState.random_sample()
#
# TypeError: random_sample() takes at most 1 positional argument (2 given)

# %% [markdown]
# # For 2d :
# # random.rand()
# # random.randn()
# # random.randint()

# %%
np.random.rand(2,3)
# Out:
# array([[0.26368406, 0.4300364 , 0.27352856],
#        [0.92209958, 0.90891158, 0.2592158 ]])

# %%
np.random.rand(3,3)
# Out:
# array([[0.42380244, 0.37276681, 0.63767386],
#        [0.27061561, 0.48752303, 0.15826359],
#        [0.50025395, 0.12778159, 0.14010898]])

# %%
np.random.randn(2,3) # standard normal distribution
# Out:
# array([[ 1.38252305,  0.46688462, -0.05682946],
#        [ 1.47388312,  1.04740126,  0.68978666]])

# %% [markdown]
# # Reshaping : same array just changing its shape
# but size will be same

# %%
arr = np.random.randint(1,4,(3,4))
arr
# Out:
# array([[3, 1, 1, 1],
#        [3, 1, 2, 3],
#        [3, 1, 3, 1]], dtype=int32)

# %%
arr.shape
# Out:
# (3, 4)

# %%
arr.reshape(6,2)
# Out:
# array([[3, 1],
#        [1, 1],
#        [3, 1],
#        [2, 3],
#        [3, 1],
#        [3, 1]], dtype=int32)

# %%
arr.reshape(12 ,1)
# Out:
# array([[3],
#        [1],
#        [1],
#        [1],
#        [3],
#        [1],
#        [2],
#        [3],
#        [3],
#        [1],
#        [3],
#        [1]], dtype=int32)

# %%
arr.reshape(-1,3) # use -1 in row/col in which we are not sure but we know any one thing atleast
# Out:
# array([[3, 1, 1],
#        [1, 3, 1],
#        [2, 3, 3],
#        [1, 3, 1]], dtype=int32)

# %% [markdown]
# # Conditional on array

# %%
arr = np.random.randint(1,3, (3,4))
arr
# Out:
# array([[2, 1, 2, 2],
#        [1, 2, 2, 2],
#        [2, 1, 1, 1]], dtype=int32)

# %%
arr > 1
# Out:
# array([[ True, False,  True,  True],
#        [False,  True,  True,  True],
#        [ True, False, False, False]])

# %%
arr[arr >1]
# Out:
# array([2, 2, 2, 2, 2, 2, 2], dtype=int32)

# %% [markdown]
# # Slicing in the array

# %%
arr
# Out:
# array([[2, 1, 2, 2],
#        [1, 2, 2, 2],
#        [2, 1, 1, 1]], dtype=int32)

# %%
# 0 to 2nd row
arr[0:3]
# Out:
# array([[2, 1, 2, 2],
#        [1, 2, 2, 2],
#        [2, 1, 1, 1]], dtype=int32)

# %%
# 0 to 2nd row and 1 and 3 col
arr[0:3 ,[1,3]]
# Out:
# array([[1, 2],
#        [2, 2],
#        [1, 1]], dtype=int32)

# %%
# 0 to 2nd row and 1 to 3rd col
arr[0:3 , 1:4]
# Out:
# array([[1, 2, 2],
#        [2, 2, 2],
#        [1, 1, 1]], dtype=int32)

# %% [markdown]
# # Mathematical operation on the 2 array

# %%
arr1 = np.random.randint(1,3,(3,4))
arr2 = np.random.randint(1,3,(3,4))

# %%
arr1
# Out:
# array([[1, 2, 2, 2],
#        [1, 1, 2, 2],
#        [2, 2, 1, 2]], dtype=int32)

# %%
arr2
# Out:
# array([[1, 1, 1, 1],
#        [2, 1, 2, 2],
#        [1, 2, 2, 1]], dtype=int32)

# %%
arr1+arr2
# Out:
# array([[2, 3, 3, 3],
#        [3, 2, 4, 4],
#        [3, 4, 3, 3]], dtype=int32)

# %%
arr1 * arr1 # this is index wise multipication , not matrix mulitpication
# Out:
# array([[1, 4, 4, 4],
#        [1, 1, 4, 4],
#        [4, 4, 1, 4]], dtype=int32)

# %%
arr1 / arr2
# Out:
# array([[1. , 2. , 2. , 2. ],
#        [0.5, 1. , 1. , 1. ],
#        [2. , 1. , 0.5, 2. ]])

# %%
m1 = np.random.randint(1,3 ,(3,4))
m2 = np.random.randint(1,3 ,(4,2))

# %%
m1 @ m2  # Matrix multipication
# Out:
# array([[5, 6],
#        [7, 9],
#        [8, 8]], dtype=int32)

# %%
m1.T
# Out:
# array([[1, 1, 1],
#        [1, 2, 1],
#        [1, 2, 2],
#        [1, 1, 2]], dtype=int32)
