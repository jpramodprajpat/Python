# %% [markdown]
# # Practice : Advance panda - 01

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Q1 . How many passengers are less than 5year

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age']<5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
len(df[df['Age'] <5]) # df[df['Age'] < 5].sum(s) or # .shape()
# Out:
# 40

# %% [markdown]
# Names of children less than 5years

# %%
df['Age']<5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.loc[df['Age'] <5 , "Name" ]
# Out:
# 7                Palsson, Master. Gosta Leonard
# 10              Sandstrom, Miss. Marguerite Rut
# 16                         Rice, Master. Eugene
# 43     Laroche, Miss. Simonne Marie Anne Andree
# 63                        Skoog, Master. Harald
# 78                Caldwell, Master. Alden Gates
# 119           Andersson, Miss. Ellis Anna Maria
# 164                Panula, Master. Eino Viljami
# 171                        Rice, Master. Arthur
# 172                Johnson, Miss. Eleanor Ileen
# 183                   Becker, Master. Richard F
# 184         Kink-Heilmann, Miss. Luise Gretchen
# 193                  Navratil, Master. Michel M
# 205                  Strom, Miss. Telma Matilda
# 261           Asplund, Master. Edvin Rojj Felix
# 297                Allison, Miss. Helen Loraine
# 305              Allison, Master. Hudson Trevor
# 340              Navratil, Master. Edmond Roger
# 348      Coutts, Master. William Loch "William"
# 374                  Palsson, Miss. Stina Viola
# ...

# %%
df[df['Age'] <5]["Name"]
# Out:
# 7                Palsson, Master. Gosta Leonard
# 10              Sandstrom, Miss. Marguerite Rut
# 16                         Rice, Master. Eugene
# 43     Laroche, Miss. Simonne Marie Anne Andree
# 63                        Skoog, Master. Harald
# 78                Caldwell, Master. Alden Gates
# 119           Andersson, Miss. Ellis Anna Maria
# 164                Panula, Master. Eino Viljami
# 171                        Rice, Master. Arthur
# 172                Johnson, Miss. Eleanor Ileen
# 183                   Becker, Master. Richard F
# 184         Kink-Heilmann, Miss. Luise Gretchen
# 193                  Navratil, Master. Michel M
# 205                  Strom, Miss. Telma Matilda
# 261           Asplund, Master. Edvin Rojj Felix
# 297                Allison, Miss. Helen Loraine
# 305              Allison, Master. Hudson Trevor
# 340              Navratil, Master. Edmond Roger
# 348      Coutts, Master. William Loch "William"
# 374                  Palsson, Miss. Stina Viola
# ...

# %%
name_list = list(df[df['Age'] <5].Name)
name_list
# Out:
# ['Palsson, Master. Gosta Leonard',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Rice, Master. Eugene',
#  'Laroche, Miss. Simonne Marie Anne Andree',
#  'Skoog, Master. Harald',
#  'Caldwell, Master. Alden Gates',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Panula, Master. Eino Viljami',
#  'Rice, Master. Arthur',
#  'Johnson, Miss. Eleanor Ileen',
#  'Becker, Master. Richard F',
#  'Kink-Heilmann, Miss. Luise Gretchen',
#  'Navratil, Master. Michel M',
#  'Strom, Miss. Telma Matilda',
#  'Asplund, Master. Edvin Rojj Felix',
#  'Allison, Miss. Helen Loraine',
#  'Allison, Master. Hudson Trevor',
#  'Navratil, Master. Edmond Roger',
#  'Coutts, Master. William Loch "William"',
#  'Palsson, Miss. Stina Viola',
#  'Nakid, Miss. Maria ("Mary")',
#  'Goodwin, Master. Sidney Leonard',
#  'Richards, Master. William Rowe',
#  'Dodge, Master. Washington',
#  'Baclini, Miss. Helene Barbara',
#  'Hirvonen, Miss. Hildur E',
#  'Quick, Miss. Phyllis May',
#  'Becker, Miss. Marion Louise',
# ...

# %% [markdown]
# How many people are less than 18 year old

# %%
df[df['Age']<18].shape
# Out:
# (113, 12)

# %%
len(df[df['Age'] < 18])
# Out:
# 113

# %% [markdown]
# # Q How many passengers pays less then the average fare

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
len(df[ df['Fare'] < df['Fare'].mean() ])
# Out:
# 680
